# %%
#Carregamento da Bibliotecas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Leitura dos dasdos e criação da Base de Dados
df_SmallCaps = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DataFramesCSV/SmallCaps2022.csv')
#Exibição de numeros de linhas e colunas
df_SmallCaps.shape
# Out:
# (1186, 7)

# %%
#Visualização do DataFrame primeiras 5 linhas
df_SmallCaps.head()
# Out:
#      Company Valuation ($B) Date Joined        Country          City   \
# 0  ByteDance           $140    4/7/2017          China        Beijing
# 1     SpaceX           $127   12/1/2012  United States      Hawthorne
# 2      SHEIN           $100    7/3/2018          China       Shenzhen
# 3     Stripe            $95   1/23/2014  United States  San Francisco
# 4      Canva            $40    1/8/2018      Australia    Surry Hills
#
#                           Industry  \
# 0          Artificial intelligence
# 1                            Other
# 2  E-commerce & direct-to-consumer
# 3                          Fintech
# 4     Internet software & services
#
#                                            Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2  Tiger Global Management, Sequoia Capital China...
# 3        Khosla Ventures, LowercaseCapital, capitalG
# 4  Sequoia Capital China, Blackbird Ventures, Mat...

# %%
#Visualização Completa do DataFrame
df_SmallCaps
# Out:
#                   Company Valuation ($B) Date Joined        Country  \
# 0               ByteDance           $140    4/7/2017          China
# 1                  SpaceX           $127   12/1/2012  United States
# 2                   SHEIN           $100    7/3/2018          China
# 3                  Stripe            $95   1/23/2014  United States
# 4                   Canva            $40    1/8/2018      Australia
# ...                   ...            ...         ...            ...
# 1181          LeadSquared             $1   6/21/2022          India
# 1182            FourKites             $1   6/21/2022  United States
# 1183          VulcanForms             $1    7/5/2022  United States
# 1184          SingleStore             $1   7/12/2022  United States
# 1185  Unstoppable Domains             $1   7/27/2022  United States
#
#               City                              Industry  \
# 0           Beijing              Artificial intelligence
# 1         Hawthorne                                Other
# 2          Shenzhen      E-commerce & direct-to-consumer
# 3     San Francisco                              Fintech
# 4       Surry Hills         Internet software & services
# ...             ...                                  ...
# 1181      Bengaluru         Internet software & services
# 1182        Chicago  Supply chain, logistics, & delivery
# 1183     Burlington  Supply chain, logistics, & delivery
# 1184  San Francisco          Data management & analytics
# 1185      Las Vegas         Internet software & services
#
#                                               Investors
# 0     Sequoia Capital China, SIG Asia Investments, S...
# 1     Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2     Tiger Global Management, Sequoia Capital China...
# 3           Khosla Ventures, LowercaseCapital, capitalG
# 4     Sequoia Capital China, Blackbird Ventures, Mat...
# ...                                                 ...
# 1181  Gaja Capital Partners, Stakeboat Capital, West...
# 1182  Hyde Park Venture Partners, Bain Capital Ventu...
# 1183  Eclipse Ventures, D1 Capital Partners, Industr...
# 1184            Google Ventures, Accel, Data Collective
# 1185              Boost VC, Draper Associates, Gaingels
#
# [1186 rows x 7 columns]

# %%
#Exibindo itens das colunas 
df_SmallCaps.columns
# Out:
# Index(['Company', 'Valuation ($B)', 'Date Joined', 'Country', 'City ',
#        'Industry', 'Investors'],
#       dtype='object')

# %%
#Renomeando dados das colunas
df_SmallCaps.rename(columns={
    'Company':'Empresa', 
    'Valuation ($B)':'ValorMercado ($)',
    'Date Joined':'DataIngresso', 
    'Country':'País', 
    'City ':'Cidade',
    'Industry' : 'Setor',
    'Investors':'Investidores'
},inplace=True)

# %%
#Exibiçãos tipos de dados da Base de dados
df_SmallCaps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1186 entries, 0 to 1185
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Empresa           1186 non-null   object
#  1   ValorMercado ($)  1186 non-null   object
#  2   DataIngresso      1186 non-null   object
#  3   País              1186 non-null   object
#  4   City              1186 non-null   object
#  5   Setor             1186 non-null   object
#  6   Investidores      1168 non-null   object
# dtypes: object(7)
# memory usage: 65.0+ KB

# %%
df_SmallCaps['Empresa']
# Out:
# 0                 ByteDance
# 1                    SpaceX
# 2                     SHEIN
# 3                    Stripe
# 4                     Canva
#                ...
# 1181            LeadSquared
# 1182              FourKites
# 1183            VulcanForms
# 1184            SingleStore
# 1185    Unstoppable Domains
# Name: Empresa, Length: 1186, dtype: object

# %%
#calculando dados nulos
df_SmallCaps.isnull().sum()
# Out:
# Empresa              0
# ValorMercado ($)     0
# DataIngresso         0
# País                 0
# City                 0
# Setor                0
# Investidores        18
# Mês                  0
# Ano                  0
# dtype: int64

# %%
#Exibindo Dados Nulos do dataframe
plt.figure(figsize=(20,5))
plt.title("Exibindo Campos Vazios")
sns.heatmap(df_SmallCaps.isnull(),cbar=False);

# %%
#Exibindo valores unicos na base-dados
df_SmallCaps.nunique()
# Out:
# Empresa             1183
# ValorMercado ($)     222
# DataIngresso         695
# País                  48
# City                 286
# Setor                 34
# Investidores        1152
# dtype: int64

# %%
#exibindo quantidade de valores unicos para a coluna escolhida
df_SmallCaps['Setor'].nunique()
# Out:
# 34

# %%
#exibindo quantidade de valores unicos para a coluna escolhida em forma de Rank
df_SmallCaps['Setor'].value_counts()
# Out:
# Fintech                                                               239
# Internet software & services                                          224
# E-commerce & direct-to-consumer                                       103
# Health                                                                 94
# Artificial intelligence                                                74
# Supply chain, logistics, & delivery                                    65
# Other                                                                  65
# Cybersecurity                                                          58
# Data management & analytics                                            45
# Auto & transportation                                                  40
# Hardware                                                               38
# Mobile & telecommunications                                            37
# Edtech                                                                 32
# Consumer & retail                                                      28
# Travel                                                                 14
# Artificial Intelligence                                                11
# Internet                                                                2
# Sequoia Capital China, ING, Alibaba Entrepreneurs Fund                  1
# Andreessen Horowitz, DST Global, IDG Capital                            1
# B Capital Group, Monk's Hill Ventures, Dynamic Parcel Distribution      1
# Vertex Ventures SE Asia, Global Founders Capital, Visa Ventures         1
# Mundi Ventures, Doqling Capital Partners, Activant Capital              1
# SingTel Innov8, Alpha JWC Ventures, Golden Gate Ventures                1
# Dragonfly Captial, Qiming Venture Partners, DST Global                  1
# Sequoia Capital China, Shunwei Capital Partners, Qualgro                1
# Tiger Global Management, Tiger Brokers, DCM Ventures                    1
# 500 Global, Rakuten Ventures, Golden Gate Ventures                      1
# Hopu Investment Management, Boyu Capital, DC Thomson Ventures           1
# Vision Plus Capital, GSR Ventures, ZhenFund                             1
# GIC. Apis Partners, Insight Partners                                    1
# Jungle Ventures, Accel, Venture Highway                                 1
# Kuang-Chi                                                               1
# Sequoia Capital, Thoma Bravo, Softbank                                  1
# Temasek, Guggenheim Investments, Qatar Investment Authority             1
# Name: Setor, dtype: int64

# %%
#exibindo quantidade de valores unicos para a coluna escolhida em forma de Rank e o parâmetro normalize exibe o rank em percentual
df_SmallCaps['Setor'].value_counts(normalize=True)
# Out:
# Fintech                                                               0.201518
# Internet software & services                                          0.188870
# E-commerce & direct-to-consumer                                       0.086847
# Health                                                                0.079258
# Artificial intelligence                                               0.062395
# Supply chain, logistics, & delivery                                   0.054806
# Other                                                                 0.054806
# Cybersecurity                                                         0.048904
# Data management & analytics                                           0.037943
# Auto & transportation                                                 0.033727
# Hardware                                                              0.032040
# Mobile & telecommunications                                           0.031197
# Edtech                                                                0.026981
# Consumer & retail                                                     0.023609
# Travel                                                                0.011804
# Artificial Intelligence                                               0.009275
# Internet                                                              0.001686
# Sequoia Capital China, ING, Alibaba Entrepreneurs Fund                0.000843
# Andreessen Horowitz, DST Global, IDG Capital                          0.000843
# B Capital Group, Monk's Hill Ventures, Dynamic Parcel Distribution    0.000843
# Vertex Ventures SE Asia, Global Founders Capital, Visa Ventures       0.000843
# Mundi Ventures, Doqling Capital Partners, Activant Capital            0.000843
# SingTel Innov8, Alpha JWC Ventures, Golden Gate Ventures              0.000843
# Dragonfly Captial, Qiming Venture Partners, DST Global                0.000843
# Sequoia Capital China, Shunwei Capital Partners, Qualgro              0.000843
# Tiger Global Management, Tiger Brokers, DCM Ventures                  0.000843
# 500 Global, Rakuten Ventures, Golden Gate Ventures                    0.000843
# Hopu Investment Management, Boyu Capital, DC Thomson Ventures         0.000843
# Vision Plus Capital, GSR Ventures, ZhenFund                           0.000843
# GIC. Apis Partners, Insight Partners                                  0.000843
# Jungle Ventures, Accel, Venture Highway                               0.000843
# Kuang-Chi                                                             0.000843
# Sequoia Capital, Thoma Bravo, Softbank                                0.000843
# Temasek, Guggenheim Investments, Qatar Investment Authority           0.000843
# Name: Setor, dtype: float64

# %%
#Exibição com gráfico de barras 
plt.figure(figsize=(30,6))
plt.title("Valores em conta corrente")
plt.bar(df_SmallCaps['Setor'].value_counts().index, df_SmallCaps['Setor'].value_counts(normalize=True));
plt.xticks(rotation=45,ha='right');

# %%
#Calculando o Percentual de empresas Criadas por país
basePaises = df_SmallCaps['País'].value_counts(normalize=True) *100
basePaises
# Out:
# United States           53.625632
# China                   14.671164
# India                    5.902192
# United Kingdom           3.878583
# Germany                  2.445194
# France                   2.023609
# Israel                   1.854975
# Canada                   1.602024
# Brazil                   1.433390
# South Korea              1.433390
# Singapore                1.096121
# Sweden                   0.674536
# Mexico                   0.674536
# Australia                0.674536
# Indonesia                0.590219
# Netherlands              0.590219
# Hong Kong                0.590219
# Ireland                  0.505902
# Japan                    0.505902
# Switzerland              0.505902
# Norway                   0.421585
# Finland                  0.337268
# Spain                    0.337268
# Turkey                   0.252951
# Colombia                 0.252951
# Belgium                  0.252951
# United Arab Emirates     0.252951
# Austria                  0.168634
# Lithuania                0.168634
# Vietnam                  0.168634
# Thailand                 0.168634
# Estonia                  0.168634
# Chile                    0.168634
# Denmark                  0.168634
# Philippines              0.168634
# Croatia                  0.168634
# South Africa             0.168634
# Czech Republic           0.084317
# Bermuda                  0.084317
# Ecuador                  0.084317
# Luxembourg               0.084317
# Malaysia                 0.084317
# Senegal                  0.084317
# Nigeria                  0.084317
# Bahamas                  0.084317
# Argentina                0.084317
# Seychelles               0.084317
# Italy                    0.084317
# Name: País, dtype: float64

# %%
#Representação em Gráfico dos Top 10 mundiais

plt.figure(figsize=(20,10))

plt.title("Top 10 Globais em Criação de small caps em 2022")
plt.pie(
    basePaises.head(10), 
    labels = basePaises.index[0:10],
    shadow=True,
    startangle=90,
    );

# %%
#Convertendo Tipo de dados String(Object) e tipo Data(time)
df_SmallCaps['DataIngresso'] = pd.to_datetime(df_SmallCaps['DataIngresso'])
#Exibindo Conversão
df_SmallCaps['DataIngresso']
# Out:
# 0      2017-04-07
# 1      2012-12-01
# 2      2018-07-03
# 3      2014-01-23
# 4      2018-01-08
#           ...
# 1181   2022-06-21
# 1182   2022-06-21
# 1183   2022-07-05
# 1184   2022-07-12
# 1185   2022-07-27
# Name: DataIngresso, Length: 1186, dtype: datetime64[ns]

# %%
#EXtração de Mês e Ano do Base de Dados e inclusão das colunas no DataFreame
df_SmallCaps['Mês'] = pd.DatetimeIndex(df_SmallCaps['DataIngresso']).month
df_SmallCaps['Ano'] = pd.DatetimeIndex(df_SmallCaps['DataIngresso']).year
df_SmallCaps.head()
# Out:
#      Empresa ValorMercado ($) DataIngresso           País          City   \
# 0  ByteDance             $140   2017-04-07          China        Beijing
# 1     SpaceX             $127   2012-12-01  United States      Hawthorne
# 2      SHEIN             $100   2018-07-03          China       Shenzhen
# 3     Stripe              $95   2014-01-23  United States  San Francisco
# 4      Canva              $40   2018-01-08      Australia    Surry Hills
#
#                              Setor  \
# 0          Artificial intelligence
# 1                            Other
# 2  E-commerce & direct-to-consumer
# 3                          Fintech
# 4     Internet software & services
#
#                                         Investidores  Mês   Ano
# 0  Sequoia Capital China, SIG Asia Investments, S...    4  2017
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...   12  2012
# 2  Tiger Global Management, Sequoia Capital China...    7  2018
# 3        Khosla Ventures, LowercaseCapital, capitalG    1  2014
# 4  Sequoia Capital China, Blackbird Ventures, Mat...    1  2018

# %%
#Criando Tabela Analitica, Realizando Agrupamento a Partir do País , mês e Ano. 
listaAgrupada = df_SmallCaps.groupby(by=['País','Mês','Ano','Empresa']).count()['Setor'].reset_index()
listaAgrupada
# Out:
#                País  Mês   Ano    Empresa  Setor
# 0         Argentina    8  2021       Uala      1
# 1         Australia    1  2018      Canva      1
# 2         Australia    3  2019  Airwallex      1
# 3         Australia    3  2022  Immutable      1
# 4         Australia    3  2022   LinkTree      1
# ...             ...  ...   ...        ...    ...
# 1181  United States   12  2021     Turing      1
# 1182  United States   12  2021       Veho      1
# 1183  United States   12  2021  YipitData      1
# 1184        Vietnam   10  2021  Sky Mavis      1
# 1185        Vietnam   12  2021       MoMo      1
#
# [1186 rows x 5 columns]

# %%
listaAgrupada.loc[
    listaAgrupada['País'] == 'Brazil'    
]
# Out:
#       País  Mês   Ano           Empresa  Setor
# 16  Brazil    1  2020              Loft      1
# 17  Brazil    1  2021    MadeiraMadeira      1
# 18  Brazil    2  2022              Neon      1
# 19  Brazil    5  2022              Dock      1
# 20  Brazil    6  2019             Loggi      1
# 21  Brazil    7  2018            Movile      1
# 22  Brazil    8  2021         Nuvemshop      1
# 23  Brazil    8  2021             Unico      1
# 24  Brazil    9  2019       QuintoAndar      1
# 25  Brazil    9  2021         CloudWalk      1
# 26  Brazil   10  2019             EBANX      1
# 27  Brazil   10  2021            CargoX      1
# 28  Brazil   11  2018             iFood      1
# 29  Brazil   12  2019  Wildlife Studios      1
# 30  Brazil   12  2020           C6 Bank      1
# 31  Brazil   12  2020          Creditas      1
# 32  Brazil   12  2021             Olist      1

# %%
listaAgrupada.loc[
   listaAgrupada['País'] == 'United States'
    
]
# Out:
#                País  Mês   Ano        Empresa  Setor
# 548   United States    1  2014         Stripe      1
# 549   United States    1  2015   Red Ventures      1
# 550   United States    1  2019      Globality      1
# 551   United States    1  2020  Alto Pharmacy      1
# 552   United States    1  2020      AppsFlyer      1
# ...             ...  ...   ...            ...    ...
# 1179  United States   12  2021      SnapLogic      1
# 1180  United States   12  2021      Tackle.io      1
# 1181  United States   12  2021         Turing      1
# 1182  United States   12  2021           Veho      1
# 1183  United States   12  2021      YipitData      1
#
# [636 rows x 5 columns]
